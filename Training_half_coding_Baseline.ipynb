# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID" # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# Importing the libraries 
import torch
import torchaudio
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import matplotlib.cm as cm
import pandas as pd
import os
import librosa
import librosa.display
import torch.nn.functional as F
from torch.autograd import Variable
import time
from Models import Autoencoder
from TestData import SingleMus
from Data_TIMIT import Data_TIMIT
import IPython.display as ipd
from IPython.display import clear_output
from Blocks import BasicBlock, Bottleneck, ChannelChange
from EntropyControl_curr import AE_control
from Baseline import Baseline

# Checking the availability of CUDA on machine
# print("Torch", torch.__version__, "CUDA", torch.version.cuda)
# print("Device:", torch.device("cuda:3"))
# print(torch.cuda.is_available())
# Out:
# /media/sdb1/hy17/venv/lib/python3.6/site-packages/numba/errors.py:131: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# - #### TIMIT Data

# %%
# overlap = 64
# data = Data_TIMIT('test', overlap = overlap)
# test_loader = torch.utils.data.DataLoader(data, batch_size = 1, shuffle \
#                                            = True, num_workers = 4)
# torch.save(test_loader, 'data/half_win_test_mul.pth')

# %%
# data = Data_TIMIT('train', mix_num = 1)
# train_loader = torch.utils.data.DataLoader(data, batch_size = 50, shuffle \
#                                            = True, num_workers = 4)
# torch.save(train_loader, 'data/half_win_train_mul.pth')

# %%
train_path = 'data/half_win_train_ctn_std4_m.pth'
test_path = 'data/half_win_test_ctn_std4_m.pth'
train_loader = torch.load(train_path)
test_loader = torch.load(test_path)

# %%
print(len(train_loader),len(test_loader))
# Out:
# 3000 300

# %%
# for c, x, c_l, x_l in test_loader:
#     break
# print(c.shape)
# print(x.shape)
# print(c_l.shape)
# print(x_l.shape)

# %%
# ipd.Audio(rebuild(mixture[0].cpu().data.numpy()), rate = 16000)

# %%
# SISDR(source, mixture)

# %% [markdown]
# #### Dummy testing, for easy running

# %% [markdown]
# Test on whole wavefiles - able to be rebuild

# %%
def SISDR(s,sr,  cuda = False):
    
    eps = 1e-20
    scale = torch.sum(sr * s, dim = 1) / torch.sum(s**2, dim = 1) 
    scale = scale.unsqueeze(dim = 1) # shape - [50,1]
    s = s * scale
    sisdr = torch.mean(10*torch.log10(torch.sum(s**2, dim = 1)/(torch.sum((s-sr)**2, dim=1)+eps)+eps))
    if cuda:
        return torch.mean(sisdr)
    else:
        return torch.mean(sisdr).cpu().data.numpy()

def SDR(s, sr, cuda = False): # input (50, 512), (50, 512)
    
    eps=1e-20
    sdr = torch.mean(10*torch.log10(torch.sum(s**2, dim = 1)/(torch.sum((s-sr)**2, dim=1)+eps)+eps))
    
    if cuda:
        return sdr
    else:
        return sdr.cpu().data.numpy()

def melMSELoss(s, sr): # input waveform(torch.Tensor)
    
    n_mels = [8, 16, 32, 128]
    loss = 0
    eps = 1e-20
    mse = nn.MSELoss()
    for n in n_mels:
        s_mel = torchaudio.transforms.MelSpectrogram(n_fft=512, n_mels=n)(s)
        sr_mel = torchaudio.transforms.MelSpectrogram(n_fft=512, n_mels=n)(sr)
        s_mel = torch.log(s_mel + eps)
        sr_mel = torch.log(sr_mel + eps)
        m = mse(s_mel, sr_mel)
        loss += m
    return loss/len(n_mels)    

def rebuild(output, overlap = 64):
    output = output.cpu()
    len_wav = len(output) * (512 - overlap) + overlap
    wave = torch.zeros(len_wav)
    for i in range(len(output)):
#         print(i)
        wave[i*(512-overlap):i*(512-overlap)+512] += output[i]       
    
    return wave

def test_newData(soft):
#     model.eval()
    sdr_list_s = []
#     sdr_list_n = []
    sdr_list_rs = []
    sdr_list_rx = []
    sdr_list_diff = []
    max_rs_sdr = 0
    max_rx_sdr = 0
    max_rs = None
    max_rx = None

    i = 0
    for wave_s, wave_x, source, mixture in test_loader: 

        source = source[0]
        mixture = mixture[0]
#         print(data)
        noise = (mixture-source).cuda()
        source = source.cuda()
        mixture = mixture.cuda()
        
        if model.stage < 2:
            target = mixture
            wave_target = wave_x
        else:
            target = source
            wave_target = wave_s
        s_h, n_h, arg_s, arg_n = model(mixture, soft=soft)
        
        sdr_list_s.append(SISDR(target, s_h))    
#         sdr_list_n.append(SISDR(noise, n_h))
        
        rs = rebuild(s_h).unsqueeze(dim = 0)
        rs_sdr = SISDR(wave_target, rs)
        sdr_list_rs.append(rs_sdr)
        
        rn = None
        if not isinstance(n_h, type(None)):
            rn = rebuild(n_h).unsqueeze(dim = 0)
            rx_sdr = SISDR(wave_x, rs+rn)
            sdr_list_rx.append(rx_sdr)
        
        if max_rs_sdr < rs_sdr:
            max_rs_sdr = rs_sdr
            max_rs = (wave_x, rs, rn)
#         if max_rx_sdr < rx_sdr:
#             max_rx_sdr = rx_sdr
#             max_rx = (rs, rn)
         
    s_score = np.mean(sdr_list_s) 
#     n_score = np.mean(sdr_list_n)
    rs_score = np.mean(sdr_list_rs)
    rx_score = np.mean(sdr_list_rx)
#     diff_score = np.mean(sdr_list_diff)
    
    return s_score, rs_score, rx_score, max_rs, arg_s, arg_n


import collections

def cal_entropy(arg):
    
    entropy = 0
    counter = collections.Counter(arg)
    sum_v = sum(counter.values())
    for value in counter.values():
        p = value / sum_v
        entropy += - np.log(p)*p
        
    return entropy


def entropy_prob(prob): # prob (bs, 512, num_m)
    
    entropy = 0
    eps = 1e-20
    prob_counter = torch.sum(prob, dim=0)
    prob_counter = torch.sum(prob_counter, dim=0)
    assert len(prob_counter) == prob.shape[-1]
    prob_counter = prob_counter / sum(prob_counter)
    entropy = - torch.sum(torch.log(prob_counter+eps)*prob_counter)
#     sum_v = sum(prob_counter)
#     for value in prob_counter:
#         p = value / sum_v
#         entropy += -torch.log(p+eps)*p
    
    return entropy

# %% [markdown]
# ## Model Define

# %%
if train_path == 'data/half_win_train_ctn_std4_m.pth':
    db = '_5db'
else:
    db = '_0db'

filters = 30
d = 3
f2 = 60
m = 128
sr = True
lr = 0.0001
weight = 1/50
target = 5
target_clean = 3
target_noise = 1
label = time.strftime("%m%d_%H%M%S")
model_name = label+'_baseline_sr32_d'+str(d)+db

# %%
hypara = '({}, {}, {}, {}, {} ({}), {}) - {} '\
      .format(filters, d, f2, m, sr, target, str(weight),\
             model_name)
print(hypara)
# Out:
# (30, 3, 60, 128, True (5), 0.02) - 0513_125250_baseline_sr32_d3_5db

# %%
model = Baseline(block = Bottleneck, scale = 10, filters = filters, d_s = d, d_n = d,\
                   f2 = f2, num_m = m, sr = sr).cuda()

lr = 0.0001
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(list(model.parameters()) + [model.means_s] + [model.means_n], lr=lr)
t = 0
# #                              ,betas = (0.9, 0.99999))
# optimizer = torch.optim.Adam(list(model.parameters()) , lr=lr) \
#                              ,betas = (0.9, 0.99999))
#                              weight_decay=1e-5)
# Out:
# BasicBlock

# %% [markdown]
# ## Train

# %% [markdown]
# baseline - sp bitrate 24
# d = 3

# %%
epochs = 50
epoch_list = []
max_sdr = (0,0,0)
max_rs = None
# target = 3.0
# target_clean = 1.45
# target_noise = 0.25
flct = 0.1
etp = 0
itermax = 0

# %%
while 1: 
    start = time.time()
    model.train()
    if t == 3:
        model.stage = 1
    if model.scale < 500:
        model.scale *= t+1
    train_sdr_s = []
    train_sdr_rs = []
    train_sdr_rx = []
    
    train_etp_cl = []
    train_etp_ns = []
    control = 0
    
    for wave_s, wave_x, source, mixture in train_loader:
        
        source = source[0]
        mixture = mixture[0]
        
        noise = (mixture - source).cuda()
        source = source.cuda()
        mixture = mixture.cuda()

        s_h, n_h, prob_s, prob_n = model(mixture, soft = True)
        
#         train_sdr_s.append(SDR(s_h, source))
#         rs = rebuild(s_h).unsqueeze(dim = 0)
#         train_sdr_rs.append(SISDR(wave_s, rs))
#         if not isinstance(n_h, type(None)):
#             rn = rebuild(n_h).unsqueeze(dim = 0)
#             train_sdr_rx.append(SISDR(wave_x, rn+rs))
#        train_mel = melMSELoss(wave_s, rs)
        
        entp_cl = None
        if not isinstance(prob_s, type(None)):
            entp_cl = entropy_prob(prob_s)
            train_etp_cl.append(entp_cl.cpu().data.numpy())
            
        if model.stage < 2:
            loss = criterion(s_h, mixture)
        else:
            loss = criterion(s_h, source) + criterion(s_h+n_h, mixture)  
        
        if etp == 1:
            if abs(target - entp_cl) > flct:
                control = 1
                loss += weight * ((target - entp_cl) ** 2)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    end = time.time()
    print('epoch_{}| Time:{:.0f} | Control:{:.0f} | Stage: {} | Itermax: {} | etp:{} '\
          .format(t, end-start, control, model.stage, itermax, etp))

#     s_s_score, s_rs_score, s_rx_score, s_diff_score, _, _, _ = test_newData(True)
    h_s_score, h_rs_score, h_rx_score, max_single_rs,  arg_s, arg_n = test_newData(False)
    
    entropy = [0, 0]

    if not isinstance(arg_s, type(None)):
        entropy[0] = cal_entropy(arg_s.data.cpu().numpy().flatten())
    if not isinstance(arg_n, type(None)):
        entropy[1] = cal_entropy(arg_n.data.cpu().numpy().flatten())
      
    epoch_list.append((h_s_score, h_rs_score,  entropy[0]))
    print('|Test-hard s: {:.2f}, rs: {:.2f}, rx: {:.2f} \n\
          |Entropy : {:.2f}, {:.2f}'\
          .format(h_s_score, h_rs_score, h_rx_score,
                  entropy[0], entropy[1]))
 #          |Test-soft s: {:.2f}, rs: {:.2f}, rx: {:.2f}, diff: {:.2f} \n\
    
    t += 1
    if model.stage >= 1:
        itermax += 1
        if h_rs_score > max_sdr[0]:
            max_sdr = (h_rs_score, h_rx_score, entropy[0], entropy[1])
            max_rs = max_single_rs
            torch.save(model, model_name+'.model')  
            itermax = 0
    
    if model.stage == 1 and etp == 0 and itermax >= 2:
        etp = 1
        itermax = 0
        max_sdr = (0,0,0,0)

#     if model.stage == 1 and itermax >= 3:
    if model.stage == 1 and etp == 1 and itermax >= 2:
        model.stage = 2  
        itermax = 0
        max_sdr = (0,0,0,0)
        print('Enter stage 2')
    
    if model.stage == 2 and itermax > 10:
        print('over')
        break
# Out:
# epoch_0| Time:252 | Control:0 | Stage: 0 | Itermax: 0 | etp:0
# |Test-hard s: 13.79, rs: 16.51, rx: nan
#           |Entropy : 0.00, 0.00
# epoch_1| Time:251 | Control:0 | Stage: 0 | Itermax: 0 | etp:0
# |Test-hard s: 22.49, rs: 23.69, rx: nan
#           |Entropy : 0.00, 0.00
# epoch_2| Time:242 | Control:0 | Stage: 0 | Itermax: 0 | etp:0
# |Test-hard s: 25.44, rs: 25.45, rx: nan
#           |Entropy : 0.00, 0.00
# epoch_3| Time:290 | Control:0 | Stage: 1 | Itermax: 0 | etp:0
# |Test-hard s: 2.10, rs: 8.36, rx: nan
#           |Entropy : 1.71, 0.00
# epoch_4| Time:291 | Control:0 | Stage: 1 | Itermax: 0 | etp:0
# |Test-hard s: 8.23, rs: 12.41, rx: nan
#           |Entropy : 2.67, 0.00
# epoch_5| Time:289 | Control:0 | Stage: 1 | Itermax: 0 | etp:0
# |Test-hard s: 6.35, rs: 11.22, rx: nan
#           |Entropy : 2.65, 0.00
# epoch_6| Time:287 | Control:0 | Stage: 1 | Itermax: 1 | etp:0
# |Test-hard s: 3.81, rs: 9.65, rx: nan
#           |Entropy : 1.72, 0.00
# epoch_7| Time:319 | Control:1 | Stage: 1 | Itermax: 0 | etp:1
# |Test-hard s: 9.58, rs: 11.40, rx: nan
#           |Entropy : 4.52, 0.00
# epoch_8| Time:319 | Control:1 | Stage: 1 | Itermax: 0 | etp:1
# |Test-hard s: 9.81, rs: 11.63, rx: nan
#           |Entropy : 4.53, 0.00
# epoch_9| Time:319 | Control:1 | Stage: 1 | Itermax: 0 | etp:1
# |Test-hard s: 10.01, rs: 11.84, rx: nan
#           |Entropy : 4.69, 0.00
# epoch_10| Time:320 | Control:1 | Stage: 1 | Itermax: 0 | etp:1
# |Test-hard s: 10.17, rs: 12.06, rx: nan
#           |Entropy : 4.66, 0.00
# epoch_11| Time:321 | Control:1 | Stage: 1 | Itermax: 0 | etp:1
# |Test-hard s: 10.28, rs: 12.12, rx: nan
#           |Entropy : 4.70, 0.00
# epoch_12| Time:325 | Control:1 | Stage: 1 | Itermax: 0 | etp:1
# |Test-hard s: 10.35, rs: 12.13, rx: nan
#           |Entropy : 4.70, 0.00
# epoch_13| Time:321 | Control:1 | Stage: 1 | Itermax: 0 | etp:1
# |Test-hard s: 10.40, rs: 12.16, rx: nan
#           |Entropy : 4.66, 0.00
# epoch_14| Time:321 | Control:1 | Stage: 1 | Itermax: 0 | etp:1
# |Test-hard s: 10.48, rs: 12.19, rx: nan
#           |Entropy : 4.64, 0.00
# epoch_15| Time:319 | Control:1 | Stage: 1 | Itermax: 0 | etp:1
# |Test-hard s: 10.40, rs: 12.15, rx: nan
#           |Entropy : 4.74, 0.00
# epoch_16| Time:325 | Control:1 | Stage: 1 | Itermax: 1 | etp:1
# |Test-hard s: 10.42, rs: 12.22, rx: nan
#           |Entropy : 4.32, 0.00
# epoch_17| Time:321 | Control:1 | Stage: 1 | Itermax: 0 | etp:1
# |Test-hard s: 10.45, rs: 12.28, rx: nan
#           |Entropy : 4.61, 0.00
# epoch_18| Time:320 | Control:1 | Stage: 1 | Itermax: 0 | etp:1
# |Test-hard s: 10.55, rs: 12.23, rx: nan
#           |Entropy : 4.24, 0.00
# epoch_19| Time:324 | Control:1 | Stage: 1 | Itermax: 1 | etp:1
# |Test-hard s: 10.45, rs: 12.22, rx: nan
#           |Entropy : 4.66, 0.00
# Enter stage 2
# epoch_20| Time:450 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -5.28, rs: 7.24, rx: 8.93
#           |Entropy : 4.69, 0.00
# epoch_21| Time:452 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -3.27, rs: 8.21, rx: 10.51
#           |Entropy : 4.63, 0.00
# epoch_22| Time:451 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -2.51, rs: 8.73, rx: 11.47
#           |Entropy : 4.72, 0.00
# epoch_23| Time:448 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -2.30, rs: 9.08, rx: 11.97
#           |Entropy : 4.45, 0.00
# epoch_24| Time:450 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -1.83, rs: 9.34, rx: 12.11
#           |Entropy : 4.74, 0.00
# epoch_25| Time:449 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -1.57, rs: 9.52, rx: 12.27
#           |Entropy : 4.73, 0.00
# epoch_26| Time:450 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -1.49, rs: 9.72, rx: 12.54
#           |Entropy : 4.65, 0.00
# epoch_27| Time:449 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -1.11, rs: 9.72, rx: 12.38
#           |Entropy : 4.69, 0.00
# epoch_28| Time:449 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -1.27, rs: 9.86, rx: 12.56
#           |Entropy : 4.70, 0.00
# epoch_29| Time:450 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -1.02, rs: 9.68, rx: 12.26
#           |Entropy : 4.71, 0.00
# epoch_30| Time:449 | Control:1 | Stage: 2 | Itermax: 1 | etp:1
# |Test-hard s: -0.90, rs: 9.95, rx: 12.55
#           |Entropy : 4.70, 0.00
# epoch_31| Time:447 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -0.73, rs: 9.96, rx: 12.50
#           |Entropy : 4.70, 0.00
# epoch_32| Time:451 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -1.47, rs: 9.91, rx: 12.56
#           |Entropy : 4.73, 0.00
# epoch_33| Time:449 | Control:1 | Stage: 2 | Itermax: 1 | etp:1
# |Test-hard s: -0.80, rs: 9.99, rx: 12.43
#           |Entropy : 4.69, 0.00
# epoch_34| Time:450 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -1.10, rs: 10.00, rx: 12.52
#           |Entropy : 4.76, 0.00
# epoch_35| Time:448 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -0.82, rs: 9.98, rx: 12.41
#           |Entropy : 4.71, 0.00
# epoch_36| Time:449 | Control:1 | Stage: 2 | Itermax: 1 | etp:1
# |Test-hard s: -0.86, rs: 10.11, rx: 12.54
#           |Entropy : 4.77, 0.00
# epoch_37| Time:449 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -0.81, rs: 10.11, rx: 12.58
#           |Entropy : 4.70, 0.00
# epoch_38| Time:447 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -1.10, rs: 10.13, rx: 12.68
#           |Entropy : 4.64, 0.00
# epoch_39| Time:447 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -0.72, rs: 10.08, rx: 12.52
#           |Entropy : 4.72, 0.00
# epoch_40| Time:448 | Control:1 | Stage: 2 | Itermax: 1 | etp:1
# |Test-hard s: -0.45, rs: 10.13, rx: 12.62
#           |Entropy : 4.75, 0.00
# epoch_41| Time:447 | Control:1 | Stage: 2 | Itermax: 2 | etp:1
# |Test-hard s: -0.98, rs: 10.14, rx: 12.59
#           |Entropy : 4.69, 0.00
# epoch_42| Time:449 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -1.00, rs: 10.15, rx: 12.67
#           |Entropy : 4.76, 0.00
# epoch_43| Time:496 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -1.11, rs: 10.01, rx: 12.42
#           |Entropy : 4.66, 0.00
# epoch_44| Time:491 | Control:1 | Stage: 2 | Itermax: 1 | etp:1
# |Test-hard s: -0.75, rs: 10.13, rx: 12.55
#           |Entropy : 4.70, 0.00
# epoch_45| Time:495 | Control:1 | Stage: 2 | Itermax: 2 | etp:1
# |Test-hard s: -0.67, rs: 10.15, rx: 12.51
#           |Entropy : 4.54, 0.00
# epoch_46| Time:485 | Control:1 | Stage: 2 | Itermax: 3 | etp:1
# |Test-hard s: -1.10, rs: 10.24, rx: 12.69
#           |Entropy : 4.75, 0.00
# epoch_47| Time:477 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -0.89, rs: 10.17, rx: 12.71
#           |Entropy : 4.69, 0.00
# epoch_48| Time:480 | Control:1 | Stage: 2 | Itermax: 1 | etp:1
# |Test-hard s: -1.11, rs: 10.20, rx: 12.63
#           |Entropy : 4.77, 0.00
# epoch_49| Time:476 | Control:1 | Stage: 2 | Itermax: 2 | etp:1
# |Test-hard s: -0.72, rs: 10.15, rx: 12.62
#           |Entropy : 4.78, 0.00
# epoch_50| Time:481 | Control:1 | Stage: 2 | Itermax: 3 | etp:1
# |Test-hard s: -0.79, rs: 10.19, rx: 12.59
#           |Entropy : 4.70, 0.00
# epoch_51| Time:476 | Control:1 | Stage: 2 | Itermax: 4 | etp:1
# |Test-hard s: -1.03, rs: 10.26, rx: 12.76
#           |Entropy : 4.69, 0.00
# epoch_52| Time:459 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -0.74, rs: 10.22, rx: 12.60
#           |Entropy : 4.77, 0.00
# epoch_53| Time:448 | Control:1 | Stage: 2 | Itermax: 1 | etp:1
# |Test-hard s: -0.75, rs: 10.18, rx: 12.58
#           |Entropy : 4.66, 0.00
# epoch_54| Time:447 | Control:1 | Stage: 2 | Itermax: 2 | etp:1
# |Test-hard s: -0.54, rs: 10.25, rx: 12.74
#           |Entropy : 4.72, 0.00
# epoch_55| Time:449 | Control:1 | Stage: 2 | Itermax: 3 | etp:1
# |Test-hard s: -0.71, rs: 10.25, rx: 12.69
#           |Entropy : 4.75, 0.00
# epoch_56| Time:448 | Control:1 | Stage: 2 | Itermax: 4 | etp:1
# |Test-hard s: -0.71, rs: 10.20, rx: 12.60
#           |Entropy : 4.75, 0.00
# epoch_57| Time:448 | Control:1 | Stage: 2 | Itermax: 5 | etp:1
# |Test-hard s: -0.65, rs: 10.28, rx: 12.76
#           |Entropy : 4.74, 0.00
# epoch_58| Time:447 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -0.75, rs: 10.21, rx: 12.57
#           |Entropy : 4.58, 0.00
# epoch_59| Time:430 | Control:1 | Stage: 2 | Itermax: 1 | etp:1
# |Test-hard s: -0.86, rs: 10.20, rx: 12.61
#           |Entropy : 4.73, 0.00
# epoch_60| Time:315 | Control:1 | Stage: 2 | Itermax: 2 | etp:1
# |Test-hard s: -0.67, rs: 10.26, rx: 12.73
#           |Entropy : 4.76, 0.00
# epoch_61| Time:319 | Control:1 | Stage: 2 | Itermax: 3 | etp:1
# |Test-hard s: -0.67, rs: 10.30, rx: 12.74
#           |Entropy : 4.77, 0.00
# epoch_62| Time:315 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -0.69, rs: 10.29, rx: 12.70
#           |Entropy : 4.73, 0.00
# epoch_63| Time:317 | Control:1 | Stage: 2 | Itermax: 1 | etp:1
# |Test-hard s: -0.59, rs: 10.24, rx: 12.71
#           |Entropy : 4.70, 0.00
# epoch_64| Time:319 | Control:1 | Stage: 2 | Itermax: 2 | etp:1
# |Test-hard s: -1.03, rs: 10.24, rx: 12.59
#           |Entropy : 4.71, 0.00
# epoch_65| Time:311 | Control:1 | Stage: 2 | Itermax: 3 | etp:1
# |Test-hard s: -1.05, rs: 10.25, rx: 12.60
#           |Entropy : 4.65, 0.00
# epoch_66| Time:305 | Control:1 | Stage: 2 | Itermax: 4 | etp:1
# |Test-hard s: -0.99, rs: 10.23, rx: 12.49
#           |Entropy : 4.70, 0.00
# epoch_67| Time:301 | Control:1 | Stage: 2 | Itermax: 5 | etp:1
# |Test-hard s: -0.51, rs: 10.31, rx: 12.78
#           |Entropy : 4.70, 0.00
# epoch_68| Time:301 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -0.52, rs: 10.27, rx: 12.65
#           |Entropy : 4.73, 0.00
# epoch_69| Time:300 | Control:1 | Stage: 2 | Itermax: 1 | etp:1
# |Test-hard s: -0.69, rs: 10.33, rx: 12.70
#           |Entropy : 4.73, 0.00
# epoch_70| Time:302 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -0.96, rs: 10.35, rx: 12.76
#           |Entropy : 4.68, 0.00
# epoch_71| Time:302 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -0.71, rs: 10.36, rx: 12.79
#           |Entropy : 4.76, 0.00
# epoch_72| Time:306 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -1.03, rs: 10.34, rx: 12.78
#           |Entropy : 4.74, 0.00
# epoch_73| Time:301 | Control:1 | Stage: 2 | Itermax: 1 | etp:1
# |Test-hard s: -0.75, rs: 10.37, rx: 12.81
#           |Entropy : 4.76, 0.00
# epoch_74| Time:304 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -0.75, rs: 10.36, rx: 12.78
#           |Entropy : 4.78, 0.00
# epoch_75| Time:300 | Control:1 | Stage: 2 | Itermax: 1 | etp:1
# |Test-hard s: -0.63, rs: 10.37, rx: 12.80
#           |Entropy : 4.77, 0.00
# epoch_76| Time:301 | Control:1 | Stage: 2 | Itermax: 2 | etp:1
# |Test-hard s: -0.87, rs: 10.39, rx: 12.83
#           |Entropy : 4.66, 0.00
# epoch_77| Time:303 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -0.89, rs: 10.42, rx: 12.87
#           |Entropy : 4.69, 0.00
# epoch_78| Time:303 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -0.60, rs: 10.35, rx: 12.60
#           |Entropy : 4.73, 0.00
# epoch_79| Time:301 | Control:1 | Stage: 2 | Itermax: 1 | etp:1
# |Test-hard s: -0.92, rs: 10.36, rx: 12.76
#           |Entropy : 4.76, 0.00
# epoch_80| Time:304 | Control:1 | Stage: 2 | Itermax: 2 | etp:1
# |Test-hard s: -0.73, rs: 10.42, rx: 12.89
#           |Entropy : 4.74, 0.00
# epoch_81| Time:301 | Control:1 | Stage: 2 | Itermax: 0 | etp:1
# |Test-hard s: -0.93, rs: 10.36, rx: 12.79
#           |Entropy : 4.72, 0.00
# epoch_82| Time:303 | Control:1 | Stage: 2 | Itermax: 1 | etp:1
# |Test-hard s: -0.53, rs: 10.30, rx: 12.74
#           |Entropy : 4.77, 0.00
# epoch_83| Time:299 | Control:1 | Stage: 2 | Itermax: 2 | etp:1
# |Test-hard s: -0.60, rs: 10.32, rx: 12.70
#           |Entropy : 4.72, 0.00
# epoch_84| Time:301 | Control:1 | Stage: 2 | Itermax: 3 | etp:1
# |Test-hard s: -0.76, rs: 10.42, rx: 12.87
#           |Entropy : 4.75, 0.00
# epoch_85| Time:302 | Control:1 | Stage: 2 | Itermax: 4 | etp:1
# |Test-hard s: -0.78, rs: 10.36, rx: 12.71
#           |Entropy : 4.73, 0.00
# epoch_86| Time:305 | Control:1 | Stage: 2 | Itermax: 5 | etp:1
# |Test-hard s: -1.03, rs: 10.40, rx: 12.82
#           |Entropy : 4.71, 0.00
# epoch_87| Time:306 | Control:1 | Stage: 2 | Itermax: 6 | etp:1
# |Test-hard s: -0.93, rs: 10.42, rx: 12.83
#           |Entropy : 4.74, 0.00

# %%
# model_name = model_name+str(max_sdr[1])[:5].replace('.','_')
output = '({}, {}, {}, {}, {}({}), {}) - {}-({:.2f},{:.2f})({:.2f},{:.2f}) '\
      .format(filters, d, f2, m, sr, target, weight,\
             model_name, max_sdr[0], max_sdr[1], max_sdr[2], max_sdr[3])
print(output)
with open('output_result.txt', 'a') as the_file:
    the_file.write(output+'\n')

# %%
rs = max_rs[1].cpu().data.numpy()[0]
rx = max_rs[1].cpu().data.numpy()[0]+max_rs[2].cpu().data.numpy()[0]
# librosa.output.write_wav(model_name+'_rs.wav', rs/max(rs), sr = 16000)
# librosa.output.write_wav(model_name+'_rx.wav', rx/max(rx), sr = 16000)

# %%
ipd.Audio(max_rs[0].cpu().data.numpy(), rate = 16000)
# librosa.output.write_wav(model, save_max_rs_1[0].cpu().data.numpy()[0], sr = 16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(rs/max(rs), rate = 16000)
# librosa.output.write_wav('0508_whole_sp32_1392rs.wav', rs/max(rs), sr = 16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(rx/max(rx), rate = 16000)
# librosa.output.write_wav('0508_whole_sp32_1392rx.wav', rx/max(rx), sr = 16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def get_n_params(model):
    count = 0
    for param in list(model.parameters()):
        nn = 1
        for s in list(param.size()):
            nn = nn*s
        count += nn
    return count
get_n_params(model)
# Out:
# 21372893

# %%
itermax

# %%
x = torch.Tensor(0).cuda()
x.cpu()
# Out:
# tensor([])

# %%
max_sdr
# Out:
# (8.352936, 12.825639, 2.788638442519023, 0)

# %%
# torch.save(model, '0509_baseline_sp24_d3.model')

# %%
# model = torch.load('0404_coding_test.model')

# %%
ipd.Audio('SAVED_RESULT/0329longtarget23_32r.wav', rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len(max_rs)
# Out:
# 3

# %%
trs = max_rs[1].cpu().data.numpy()[0]
trx = (max_rs[1]+max_rs[2]).cpu().data.numpy()[0]

# %%
ipd.Audio(max_rs[0].cpu().data.numpy()[0], rate = 16000)
# librosa.output.write_wav('0423_a4_19_12rs.wav', max_rs[0].cpu().data.numpy()[0], sr = 16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(trs/max(trs), rate = 16000)
# librosa.output.write_wav('0508_baseline_sp24_d3_0835rs.wav', trs/max(trs), sr = 16000)

# %%
ipd.Audio(trx/max(trx), rate = 16000)
# librosa.output.write_wav('0508_baseline_sp24_d3_1282rx.wav', trx/max(trx), sr = 16000)

# %%
ipd.Audio(max_rs[1].cpu().data.numpy()[0], rate = 16000)
# librosa.output.write_wav('0326noMask11_6r.wav', max_rs.cpu().data.numpy()[0], sr = 16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
criterion(outputs, data)

# %%
import matplotlib.pyplot as plt
plt.hist(arg.data.cpu().numpy().flatten())

# %% [markdown]
# ## Test

# %% [markdown]
# Test methods on truncated data

# %%
def SISDR(s,sr,  cuda = False):
    
    eps = 1e-20
    scale = torch.sum(sr * s, dim = 1) / torch.sum(s**2, dim = 1) 
    scale = scale.unsqueeze(dim = 1) # shape - [50,1]
    s = s * scale
    sisdr = torch.mean(10*torch.log10(torch.sum(s**2, dim = 1)/(torch.sum((s-sr)**2, dim=1)+eps)+eps))
    if cuda:
        return torch.mean(sisdr)
    else:
        return torch.mean(sisdr).cpu().data.numpy()

def SDR(s, sr, cuda = False): # input (50, 512), (50, 512)
    
    eps=1e-20
    sdr = torch.mean(10*torch.log10(torch.sum(s**2, dim = 1)/(torch.sum((s-sr)**2, dim=1)+eps)+eps))
    
    if cuda:
        return sdr
    else:
        return sdr.cpu().data.numpy()


def rebuild(output, overlap = overlap):
    len_wav = len(output) * (512 - overlap) + overlap
    wave = np.zeros(len_wav)
    for i in range(len(output)):
#         print(i)
        wave[i*(512-overlap):i*(512-overlap)+512] += output[i]       
    
    return wave

def test_qtz(soft):
#     model.eval()
    sdr_list_s = []
    sdr_list_n = []
    i = 0

    for source, mixture in test_loader:
#         print(data)
#         print(i)
#         i+=1
        noise = (mixture-source).cuda()
        source = source.cuda()
        mixture = mixture.cuda()
        target = source
        
        s_h, n_h, arg_s, arg_n = model(mixture, soft)
        # arg will be None when doing softquantization

        sdr_list_s.append(SDR(noise, n_h))
        sdr_list_n.append(SDR(source, s_h))
        
    s_score = np.mean(sdr_list_s) 
    n_score = np.mean(sdr_list_n) 
    
    return s_score, n_score, arg_s, arg_n


def test_no_qtz():
#     model.eval()
    sdr_list_s = []
    sdr_list_n = []
    i = 0
    for source, mixture in test_loader:

#         print(data)
        noise = (mixture-source).cuda()
        source = source.cuda()
        mixture = mixture.cuda()
        s_h, n_h = model.test_no_qtz(mixture)
#         print(outputs)

        sdr_list_s.append(SDR(noise, n_h))
        sdr_list_n.append(SDR(source, s_h))
    
    s_score = np.mean(sdr_list_s) 
    n_score = np.mean(sdr_list_n)
    
    return s_score, n_score


import collections

def cal_entropy(arg):
    
    entropy = 0
    counter = collections.Counter(arg)
    sum_v = sum(counter.values())
    for value in counter.values():
        p = value / sum_v
        entropy += - np.log(p)*p
        
    return entropy

# %%
# path = '/media/sdc1/Data/ETRI_Music/'
# test_data = SingleMus(path)
# bs = 50
# test_loader = torch.utils.data.DataLoader(test_data, batch_size = bs, shuffle \
#                                          = True, num_workers = 4)
# torch.save(test_loader, 'mus_test_dataloader.pth')

# %%
# test_loader = torch.load('mus_test_dataloader.pth')

# %%
# model = Autoencoder().cuda()
# model.load_state_dict(torch.load('0217_initiate.model'))

# %% [markdown]
# ## Listenning Test

# %%
def trim(c):

    trim_len = int((len(c)//512)*512)
    c = c[:trim_len].reshape(-1, 512)

    return c

def rebuild(output):
    output = output.data.cpu().numpy()
    output = output.flatten()
    
    return output

def SDR(s, sr): # input (50, 512), (50, 512)
    
    eps=1e-20
    s = s.cpu().data.numpy()
    sr = sr.cpu().data.numpy()
    sdr = 10*np.log10(np.sum(s**2)/(np.sum((s-sr)**2)+eps)+eps)
    
    return sdr

# %%
# Compute entropy
import collections
def entropy(arg):
    entropy = 0
    counter = collections.Counter(arg)
    sum_v = sum(counter.values())
    for value in counter.values():
        p = value / sum_v
        entropy += - np.log(p)*p
    return entropy
    
# entropy(x)

# %%
x = [1,2,3,5,5,5,5,5,5,5,5,5]
plt.hist(x)
# Out:
# (array([1., 0., 1., 0., 0., 1., 0., 0., 0., 9.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <a list of 10 Patch objects>)

# %%
import IPython.display
import matplotlib.pyplot as plt
wavpath1 = '/media/sdc1/Data/timit-wav/train/dr1/fcjf0/sa1.wav'
wavpath2 = '/media/sdc1/Data/timit-wav/train/dr1/fcjf0/sa2.wav'
c1, cr = librosa.load(wavpath1, sr=None)
c1 = c1/max(c1)
idx = 1
names = ['birds', 'computerkeyboard', 'jungle', 'ocean', 'casino', 'eatingchips', 'machineguns',\
                 'cicadas', 'frogs', 'motorcycles']
noise_path = '/media/sdc1/Data/Duan/{}.wav'.format(names[idx])
n, nr = librosa.load(noise_path, sr=None)
n = n/max(n)
# c2, cr = librosa.load(wavpath2, sr=None)
# c1_, cr = librosa.load(wavpath1)
# c1, c2 = c1/np.max(c1), c2/np.max(c2)
n = n[len(n)//2:len(n)//2+len(c1)]
mixture = n + c1

# %%
# mixture = 0.1 * n[len(n)//2:len(n)//2+len(c1)] + c1

# %%
IPython.display.Audio(mixture, rate = cr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# # model = Autoencoder(block = Bottleneck,d = 15, num_m = 32, soft = True).cuda()
# model = torch.load('0304_entropy_control.model')

# %%
model.eval()
data = torch.Tensor(trim(mixture)).cuda()
clean = torch.Tensor(trim(c1)).cuda()
s_h, n_h, arg_s, arg_n = model(data, soft = False)

# %%
noise = torch.Tensor(trim(n)).cuda()
SDR(clean, n_h)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cf72c90e155f> in <module>
# ----> 1 noise = torch.Tensor(trim(n)).cuda()
#       2 SDR(clean, n_h)
#
# NameError: name 'torch' is not defined

# %%
data = torch.Tensor(trim(mixture)).cuda()
clean = torch.Tensor(trim(c1)).cuda()

# %%
dist = arg_n.data.cpu().numpy().flatten()
entropy(dist)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-97414594cd11> in <module>
# ----> 1 dist = arg_n.data.cpu().numpy().flatten()
#       2 entropy(dist)
#
# AttributeError: 'NoneType' object has no attribute 'data'

# %%
# IPython.display.Audio(mixture, rate = cr)

# %%
IPython.display.Audio(rebuild(n_h), rate = cr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data = torch.Tensor(trim(c1[:length])).cuda()
output1, arg1 = model.test_hard_qtz(data)
data = torch.Tensor(trim(c2[:length])).cuda()
output2, arg2 = model.test_hard_qtz(data)

# %%
IPython.display.Audio(rebuild(output1)/max(c1)+rebuild(output2)/max(c2), rate = cr)

# %%
muspath1 = '/media/sdc1/Data/ETRI_Music/1349-00002-RFO.wav'
m1, mr = librosa.load(muspath1)

# %%
plt.plot(m1)

# %%
dist1 = arg1.data.cpu().numpy().flatten()
dist2 = arg2.data.cpu().numpy().flatten()
dist_stk = np.hstack((dist1, dist2))

# %%
dist_stk.shape

# %%
print(entropy(dist1), entropy(dist2), entropy(dist), entropy(dist_stk))

# %%
entropy(arg)

# %%
x.reshape(-1, 3)
